# %% [markdown]
# # University of Stirling
#
# # ITNPBD2 Representing and Manipulating Data
#
# # Assignment Autumn 2023
#
# # A Consultancy Job for JC Penney
#
# This notebook forms the assignment instructions and submission document of the assignment for ITNPBD2. Read the instructions carefully and enter code into the cells as indicated.
#
# You will need these five files, which were in the Zip file you downloaded from the course webpage:
#
# - jcpenney_reviewers.json
# - jcpenney_products.json
# - products.csv
# - reviews.csv
# - users.csv
#
# The data in these files describes products that have been sold by the American retail giant, JC Penney, and reviews by customers who bought them. Note that the product data is real, but the customer data is synthetic.
#
# Your job is to process the data, as requested in the instructions in the markdown cells in this notebook.

# %% [markdown]
# # Completing the Assignment
#
# Rename this file to be xxxxxx_BD2 where xxxxxx is your student number, then type your code and narrative description into the boxes provided. Add as many code and markdown cells as you need. The cells should contain:
#
# - **Text narrative describing what you did with the data**
# - **The code that performs the task you have described**
# - **Comments that explain your code**

# %% [markdown]
# # Marking Scheme
# The assessment will be marked against the university Common Marking Scheme (CMS)
#
# Here is a summary of what you need to achieve to gain a grade in the major grade bands:
#
# |Grade|Requirement|
# |:---|:---|
# | Fail | You will fail if your code does not run or does not achieve even the basics of the task. You may also fail if you submit code without either comments or a text explanation of what the code does.|
# | Pass | To pass, you must submit sufficient working code to show that you have mastered the basics of the task, even if not everything works completely. You must include some justifications for your choice of methods, but without mentioning alternatives. |
# | Merit | For a merit, your code must be mostly correct, with only small problems or parts missing, and your comments must be useful rather than simply re-stating the code in English. Most choices for methods and structures should be explained and alternatives mentioned. |
# | Distinction | For a distinction, your code must be working, correct, and well commented and shows an appreciation of style, efficiency and reliability. All choices for methods and structures are concisely justified and alternatives are given well thought considerations. For a distinction, your work should be good enough to present to executives at the company.|
#
# The full details of the CMS can be found here
#
# https://www.stir.ac.uk/about/professional-services/student-academic-and-corporate-services/academic-registry/academic-policy-and-practice/quality-handbook/assessment-policy-and-procedure/appendix-2-postgraduate-common-marking-scheme/
#
# Note that this means there are not certain numbers of marks allocated to each stage of the assignment. Your grade will reflect how well your solutions and comments demonstrate that you have achieved the learning outcomes of the task.

# %% [markdown]
# ## Submission
# When you are ready to submit, **print** your notebook as PDF (go to File -> Print Preview) in the Jupyter menu. Make sure you have run all the cells and that their output is displayed. Any lines of code or comments that are not visible in the pdf should be broken across several lines. You can then submit the file online.
#
# Late penalties will apply at a rate of three marks per day, up to a maximum of 7 days. After 7 days you will be given a mark of 0. Extensions will be considered under acceptable circumstances outside your control.
#
# ## Academic Integrity
#
# This is an individual assignment, and so all submitted work must be fully your own work.
#
# The University of Stirling is committed to protecting the quality and standards of its awards. Consequently, the University seeks to promote and nurture academic integrity, support staff academic integrity, and support students to understand and develop good academic skills that facilitate academic integrity.
#
# In addition, the University deals decisively with all forms of Academic Misconduct.
#
# Where a student does not act with academic integrity, their work or behaviour may demonstrate Poor Academic Practice or it may represent Academic Misconduct.
#
# ### Poor Academic Practice
#
# Poor Academic Practice is defined as: "The submission of any type of assessment with a lack of referencing or inadequate referencing which does not effectively acknowledge the origin of words, ideas, images, tables, diagrams, maps, code, sound and any other sources used in the assessment."
#
# ### Academic Misconduct
#
# Academic Misconduct is defined as: "any act or attempted act that does not demonstrate academic integrity and that may result in creating an unfair academic advantage for you or another person, or an academic disadvantage for any other member or member of the academic community."
#
# Plagiarism is presenting somebody else’s work as your own **and includes the use of artificial intelligence tools such as GPT or CoPilot**. Plagiarism is a form of academic misconduct and is taken very seriously by the University. Students found to have plagiarised work can have marks deducted and, in serious cases, even be expelled from the University. Do not submit any work that is not entirely your own. Do not collaborate with or get help from anybody else with this assignment.
#
# The University of Stirling's full policy on Academic Integrity can be found at:
#
# https://www.stir.ac.uk/about/professional-services/student-academic-and-corporate-services/academic-registry/academic-policy-and-practice/quality-handbook/academic-integrity-policy-and-academic-misconduct-procedure/

# %% [markdown]
# ## The Assignment
# Your task with this assignment is to use the data provided to demonstrate your Python data manipulation skills.
#
# There are three `.csv` files and two `.json` files so you can process different types of data. The files also contain unstructured data in the form of natural language in English and links to images that you can access from the JC Penney website (use the field called `product_image_urls`).
#
# Start with easy tasks to show you can read in a file, create some variables and data structures, and manipulate their contents. Then move onto something more interesting.
#
# Look at the data that we provided with this assessment and think of something interesting to do with it using whatever libraries you like. Describe what you decide to do with the data and why it might be interesting or useful to the company to do it.
#
# You can add additional data if you need to - either download it or access it using `requests`. Produce working code to implement your ideas in as many cells as you need below. There is no single right answer, the aim is to simply show you are competent in using python for data analysis. Exactly how you do that is up to you.
#
# For a distinction class grade, this must show originality, creative thinking, and insights beyond what you've been taught directly on the module.

# %% [markdown]
# ## Structure
# You may structure the project how you wish, but here is a suggested guideline to help you organise your work:
#
#  1. Data Exploration - Explore the data and show you understand its structure and relations
#  2. Data Validation - Check the quality of the data. Is it complete? Are there obvious errors?
#  3. Data Visualisation - Gain an overall understanding of the data with visualisations
#  4. Data Analysis = Set some questions and use the data to answer them
#  5. Data Augmentation - Add new data from another source to bring new insights to the data you already have

# %% [markdown]
# # Remember to make sure you are working completely on your own.
# # Don't work in a group or with a friend
# You may NOT use any automated code generation or analytics tools for this assignment, so do not use tools like GPT. You can look up the syntax for the functions you use, but you must write the code yourself and the comments must provide an insightful analysis of the results.

# %%
# Put your code and comments in cells below here
# Add as many cells as you need

# %% [markdown]
# # **Libraries to import**

# %%
#necessary libraries for data analysis,visualization and natural language processing are imported

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# %% [markdown]
# Reading CSV and JSON files

# %%
#Reading JSON files for  products and reviewers
import json
with open("/content/jcpenney_products.json", "r") as file:
    products_json= [json.loads(line) for line in file]
with open("/content/jcpenney_reviewers.json", "r") as file:
    reviewers_json = [json.loads(line) for line in file]

# Reading product,review,user files from CSV files
products_csv=pd.read_csv("/content/products.csv")
reviews_csv=pd.read_csv("/content/reviews.csv")
users_csv=pd.read_csv("/content/users.csv")

# %%
#Displaying the first two rows of json products table
products_json=pd.DataFrame(products_json)
products_json.head(2)
# Out:
#                             uniq_id           sku  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
#
#                                     name_title  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          description list_price sale_price  \
# 0  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 1  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
#
#         category                 category_tree  average_product_rating  \
# 0  alfred dunner  jcpenney|women|alfred dunner                   2.625
# 1  alfred dunner  jcpenney|women|alfred dunner                   3.000
#
#                                          product_url  \
# 0  http://www.jcpenney.com/alfred-dunner-essentia...
# 1  http://www.jcpenney.com/alfred-dunner-essentia...
#
#                                   product_image_urls          brand  \
# 0  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
# 1  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
#
#    total_number_reviews                                            Reviews  \
# 0                     8  [{'User': 'fsdv4141', 'Review': 'You never hav...
# 1                     8  [{'User': 'tpcu2211', 'Review': 'You never hav...
#
#                                          Bought With
# 0  [898e42fe937a33e8ce5e900ca7a4d924, 8c02c262567...
# 1  [bc9ab3406dcaa84a123b9da862e6367d, 18eb69e8fc2...

# %%
#Displaying the first two rows of json reviews table
reviewers_json=pd.DataFrame(reviewers_json)
reviewers_json
# Out:
#       Username         DOB          State  \
# 0     bkpn1412  31.07.1983         Oregon
# 1     gqjs4414  27.07.1998  Massachusetts
# 2     eehe1434  08.08.1950          Idaho
# 3     hkxj1334  03.08.1969        Florida
# 4     jjbd1412  26.07.2001        Georgia
# ...        ...         ...            ...
# 4995  mfnn1212  27.07.1997       Delaware
# 4996  ejnb3414  01.08.1976      Minnesota
# 4997  pdzw1433  28.07.1994           Ohio
# 4998  npha1342  07.08.1953        Montana
# 4999  yuoc2324  02.08.1975   South Dakota
#
#                                                Reviewed
# 0                    [cea76118f6a9110a893de2b7654319c0]
# 1                    [fa04fe6c0dd5189f54fe600838da43d3]
# 2                                                    []
# 3     [f129b1803f447c2b1ce43508fb822810, 3b0c9bc0be6...
# 4                                                    []
# ...                                                 ...
# 4995                 [d6cd506246bd17afa611b6a06236713c]
# 4996                 [97de1506cd0bcbe50f2797cd0588eb81]
# 4997  [799d62906019d910fa744987da184ae7, b8f5deb7b02...
# 4998                 [6250b1d691cd3842f05b87736f2fadbf]
# 4999                                                 []
#
# [5000 rows x 4 columns]

# %%
#Displaying the first two rows of products
products_csv.head(2)
# Out:
#                             Uniq_id           SKU  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
#
#                                           Name  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          Description  Price  Av_Score
# 0  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 1  Youll return to our Alfred Dunner pull-on capr...  41.09     3.000

# %%
#Displaying the first two rows of reviews
reviews_csv.head(2)
# Out:
#                             Uniq_id  Username  Score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
#
#                                               Review
# 0  You never have to worry about the fit...Alfred...
# 1  Good quality fabric. Perfect fit. Washed very ...

# %%
#Displaying the first two rows of users
users_csv.head(2)
# Out:
#    Username         DOB          State
# 0  bkpn1412  31.07.1983         Oregon
# 1  gqjs4414  27.07.1998  Massachusetts

# %% [markdown]
#  Merging CSV and JSON data - Products table

# %%
# Merge products dataframes on 'Uniq_id'
merged_products = pd.concat([products_csv.set_index('Uniq_id'), products_json.set_index('uniq_id')], axis=1, join='inner').reset_index()
merged_products.head(2)
# Out:
#                               index           SKU  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
#
#                                           Name  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          Description  Price  Av_Score  \
# 0  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 1  Youll return to our Alfred Dunner pull-on capr...  41.09     3.000
#
#             sku                                   name_title  \
# 0  pp5006380337  Alfred Dunner® Essential Pull On Capri Pant
# 1  pp5006380337  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          description list_price sale_price  \
# 0  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 1  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
#
#         category                 category_tree  average_product_rating  \
# 0  alfred dunner  jcpenney|women|alfred dunner                   2.625
# 1  alfred dunner  jcpenney|women|alfred dunner                   3.000
#
#                                          product_url  \
# 0  http://www.jcpenney.com/alfred-dunner-essentia...
# 1  http://www.jcpenney.com/alfred-dunner-essentia...
#
#                                   product_image_urls          brand  \
# 0  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
# 1  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
#
#    total_number_reviews                                            Reviews  \
# 0                     8  [{'User': 'fsdv4141', 'Review': 'You never hav...
# 1                     8  [{'User': 'tpcu2211', 'Review': 'You never hav...
#
#                                          Bought With
# 0  [898e42fe937a33e8ce5e900ca7a4d924, 8c02c262567...
# 1  [bc9ab3406dcaa84a123b9da862e6367d, 18eb69e8fc2...

# %% [markdown]
#  Merging CSV and JSON data - Products,reviews table

# %%
#Breaking the reviewed column of reviews to find the matching uniq id with products table
products_exploded = reviewers_json.explode('Reviewed')

# %%
reviews_products_list = pd.merge(merged_products, products_exploded, left_on='index', right_on='Reviewed', how='inner')

# %% [markdown]
# ##  Missing values altering

# %%
#As the space value is not recognized as a null value, it is modified to null to identify the original empty values
merged_products.replace('', pd.NA, inplace=True)
merged_products.isnull().sum()
# Out:
# index                        0
# SKU                         67
# Name                         0
# Description                543
# Price                     2166
# Av_Score                     0
# sku                         67
# name_title                   0
# description                543
# list_price                2166
# sale_price                  18
# category                   636
# category_tree              636
# average_product_rating       0
# product_url                  0
# product_image_urls         157
# brand                        0
# total_number_reviews         0
# Reviews                      0
# Bought With                  0
# dtype: int64

# %%
#Updating the category with most repeated category name
mode=merged_products['category'].mode()
merged_products['category'] = merged_products['category'].fillna(mode)

# %%
# Dropping the null values of sale price with its mean
merged_products['sale_price'] = pd.to_numeric(merged_products['sale_price'], errors='coerce')

mean=merged_products['sale_price'].mean()
merged_products['sale_price'] = merged_products['sale_price'].fillna(mean)

# %% [markdown]
# ### **Analysing the jc penny dataset**

# %% [markdown]
# **1. Sentiment analysis for reviews for top 10 brands**

# %%
# Function to extract the  review from reviews column
def extract_first_review(reviews):
    if isinstance(reviews, list) and len(reviews) > 0:
        return reviews[0].get('Review')
    return None

# Applying the function to extract the first review and creating a new 'Review' column
reviews_products_list['Review'] = reviews_products_list['Reviews'].apply(extract_first_review)

# %%
from textblob import TextBlob

# Function to determine sentiment to check if it postive,negative or neutral comment
def analyze_sentiment(review):
    if review:
        analysis = TextBlob(review)
        # Classify as positive, negative, or neutral
        return 'Positive' if analysis.sentiment.polarity > 0 else 'Negative' if analysis.sentiment.polarity < 0 else 'Neutral'
    return None

# Applying sentiment analysis to the 'Review' column and creating a new 'Sentiment' column
reviews_products_list['Sentiment'] = reviews_products_list['Review'].apply(analyze_sentiment)

# Displaying the resulting DataFrame with 'Sentiment' column
reviews_products_list[['brand', 'Review', 'Sentiment']]
# Out:
#                      brand                                             Review  \
# 0            Alfred Dunner  You never have to worry about the fit...Alfred...
# 1            Alfred Dunner  You never have to worry about the fit...Alfred...
# 2            Alfred Dunner  You never have to worry about the fit...Alfred...
# 3            Alfred Dunner  You never have to worry about the fit...Alfred...
# 4            Alfred Dunner  You never have to worry about the fit...Alfred...
# ...                    ...                                                ...
# 7977                Hoover  1) the hose is TOO short. its a stretch to cle...
# 7978                Hoover  1) the hose is TOO short. its a stretch to cle...
# 7979                Hoover  1) the hose is TOO short. its a stretch to cle...
# 7980  Asstd National Brand  This product is just fine for a summer bedspre...
# 7981  Asstd National Brand  This product is just fine for a summer bedspre...
#
#      Sentiment
# 0     Positive
# 1     Positive
# 2     Positive
# 3     Positive
# 4     Positive
# ...        ...
# 7977  Positive
# 7978  Positive
# 7979  Positive
# 7980  Positive
# 7981  Positive
#
# [7982 rows x 3 columns]

# %% [markdown]
# THis graph shows that most of reviews are positive for all the brands

# %%
import plotly.express as px

# Extracting Top 10 brands
top_brands = reviews_products_list['brand'].value_counts().nlargest(10).index

# Filter  for top 10 brands
top_brands_df = reviews_products_list[reviews_products_list['brand'].isin(top_brands)]

# Grouping by brand and sentiment.Then calculate its proportions
sentiment_proportions = (
    top_brands_df.groupby(['brand', 'Sentiment'])
    .size()
    .unstack(fill_value=0)
    .apply(lambda x: x / x.sum(), axis=1)
    .stack()
    .reset_index(name='Proportion')
)

# Creating a bar chart using Plotly Express
fig = px.bar(sentiment_proportions, x='brand', y='Proportion', color='Sentiment',
             labels={'Proportion': 'Sentiment Proportion'}, barmode='group',
             title='Sentiment Proportion for Top 10 Brands')

# Showing the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="09a5448a-4c6d-4e67-9f02-68cc3ac84f3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09a5448a-4c6d-4e67-9f02-68cc3ac84f3e")) {                    Plotly.newPlot(                        "09a5448a-4c6d-4e67-9f02-68cc3ac84f3e",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=Negative\u003cbr\u003ebrand=%{x}\u003cbr\u003eSentiment Proportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"textposition":"auto","x":["A.N.A","ARIZONA","Asstd National Brand","LIZ CLAIBORNE","Nike","STAFFORD","STYLUS","St. John's Bay","WORTHINGTON","Xersion"],"xaxis":"x","y":[0.07853403141361257,0.05084745762711865,0.1054421768707483,0.041237113402061855,0.07222222222222222,0.07792207792207792,0.10240963855421686,0.08181818181818182,0.037914691943127965,0.0234375],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Neutral\u003cbr\u003ebrand=%{x}\u003cbr\u003eSentiment Proportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neutral","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","x":["A.N.A","ARIZONA","Asstd National Brand","LIZ CLAIBORNE","Nike","STAFFORD","STYLUS","St. John's Bay","WORTHINGTON","Xersion"],"xaxis":"x","y":[0.005235602094240838,0.03389830508474576,0.047619047619047616,0.010309278350515464,0.03333333333333333,0.021645021645021644,0.030120481927710843,0.013636363636363636,0.014218009478672985,0.046875],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=Positive\u003cbr\u003ebrand=%{x}\u003cbr\u003eSentiment Proportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"textposition":"auto","x":["A.N.A","ARIZONA","Asstd National Brand","LIZ CLAIBORNE","Nike","STAFFORD","STYLUS","St. John's Bay","WORTHINGTON","Xersion"],"xaxis":"x","y":[0.9162303664921466,0.9152542372881356,0.8469387755102041,0.9484536082474226,0.8944444444444445,0.9004329004329005,0.8674698795180723,0.9045454545454545,0.9478672985781991,0.9296875],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0," ...

# %% [markdown]
# 2. Age group distribution

# %% [markdown]
# From the below graph we can confirm that most reviewed people are falling in the age group between 61 to 70 and least reviwed age group is 71+

# %%
# Converting 'DOB' to datetime
from datetime import datetime
reviews_products_list['DOB'] = pd.to_datetime(reviews_products_list['DOB'])

# Calculating age
reviews_products_list['age'] = (datetime.now() - reviews_products_list['DOB']).astype('<m8[Y]')

# Defining age groups
bins = [0, 18, 30, 40, 50, 60, 70, 120]
labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '61-70', '71+']

# Creating 'Age Group' column
reviews_products_list['Age Group'] = pd.cut(reviews_products_list['age'], bins=bins, labels=labels, right=False)

# Counting the occurrences of each age group
age_group_counts = reviews_products_list['Age Group'].value_counts()

# Creating a pie chart
fig = px.pie(age_group_counts, names=age_group_counts.index, values=age_group_counts.values,
             title='Proportion of Age Groups',
             labels={'index': 'Age Group', 'value': 'Count'},
             hole=0.4)

# Showing the figure
fig.show()
# Out:
# <ipython-input-19-19b48d39182f>:3: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6f8d7ba9-e883-4081-92c1-f2c53c945c34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f8d7ba9-e883-4081-92c1-f2c53c945c34")) {                    Plotly.newPlot(                        "6f8d7ba9-e883-4081-92c1-f2c53c945c34",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Age Group=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["61-70","51-60","31-40","41-50","19-30","71+","0-18"],"legendgroup":"","name":"","showlegend":true,"values":[1575,1550,1517,1489,1200,651,0],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker ...

# %% [markdown]
# 3. State wise sum of sale prices for each state.

# %%
# Creating a code for each state and mapping to it to show in a map
state_to_code_mapping = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands': 'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'U.S. Virgin Islands': 'VI',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

reviews_products_list['State Code'] = reviews_products_list['State'].map(state_to_code_mapping)
reviews_products_list['list_price']=pd.to_numeric(reviews_products_list['list_price'])
reviews_products_list['list_price']
# Out:
# 0        41.09
# 1        41.09
# 2        41.09
# 3        41.09
# 4        41.09
#          ...
# 7977    201.97
# 7978    201.97
# 7979    201.97
# 7980       NaN
# 7981       NaN
# Name: list_price, Length: 7982, dtype: float64

# %%
reviews_products_list.head(2)
# Out:
#                               index           SKU  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
#
#                                           Name  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          Description  Price  Av_Score  \
# 0  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 1  Youll return to our Alfred Dunner pull-on capr...  41.09     3.000
#
#             sku                                   name_title  \
# 0  pp5006380337  Alfred Dunner® Essential Pull On Capri Pant
# 1  pp5006380337  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          description  list_price  ...  \
# 0  You'll return to our Alfred Dunner pull-on cap...       41.09  ...
# 1  You'll return to our Alfred Dunner pull-on cap...       41.09  ...
#
#                                          Bought With  Username        DOB  \
# 0  [898e42fe937a33e8ce5e900ca7a4d924, 8c02c262567...  yemw3321 1991-07-29
# 1  [bc9ab3406dcaa84a123b9da862e6367d, 18eb69e8fc2...  oofb2342 1989-07-29
#
#        State                          Reviewed  \
# 0  Tennessee  b6c0b6bea69c722939585baeac73c13d
# 1  Wisconsin  93e5272c51d8cce02597e3ce67b7ad0a
#
#                                               Review Sentiment   age  \
# 0  You never have to worry about the fit...Alfred...  Positive  32.0
# 1  You never have to worry about the fit...Alfred...  Positive  34.0
#
#   Age Group State Code
# 0     31-40         TN
# 1     31-40         WI
#
# [2 rows x 29 columns]

# %%
import plotly.graph_objects as go
import pandas as pd

# Converting 'State Code' to string
reviews_products_list['State Code'] = reviews_products_list['State Code'].astype(str)

# Grouping by state code to find the sum of list price for each state
reviews_products_state_sum = reviews_products_list.groupby('State Code')['list_price'].sum().reset_index()

# Create choropleth map
fig = go.Figure(data=go.Choropleth(
    locations=reviews_products_state_sum['State Code'],
    z=reviews_products_state_sum['list_price'],
    locationmode='USA-states',
    colorscale='YlOrRd',
    colorbar_title='Total List Prices'
))

fig.update_layout(
    title_text='Total List Prices by State',
    geo=dict(
        scope='usa',
        projection_scale=7,
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3c46ec7-584c-4e40-b968-edec5a44d337" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3c46ec7-584c-4e40-b968-edec5a44d337")) {                    Plotly.newPlot(                        "a3c46ec7-584c-4e40-b968-edec5a44d337",                        [{"colorbar":{"title":{"text":"Total List Prices"}},"colorscale":[[0.0,"rgb(255,255,204)"],[0.125,"rgb(255,237,160)"],[0.25,"rgb(254,217,118)"],[0.375,"rgb(254,178,76)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(252,78,42)"],[0.75,"rgb(227,26,28)"],[0.875,"rgb(189,0,38)"],[1.0,"rgb(128,0,38)"]],"locationmode":"USA-states","locations":["AK","AL","AR","AS","AZ","CA","CO","CT","DC","DE","FL","GA","GU","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MP","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VA","VI","VT","WA","WI","WV","WY","nan"],"z":[15084.01,16766.86,10056.68,18177.71,9763.31,13686.14,12162.7,16198.02,8976.58,13930.86,13680.25,7944.01,18191.73,13051.88,18897.01,13219.710000000001,9461.94,20441.02,16845.61,23910.81,14384.55,13345.0,8689.49,14058.27,12038.94,16293.14,11986.35,33544.799999999996,27354.11,11661.82,7096.94,11045.38,13437.64,16383.890000000001,15730.78,18387.06,21648.739999999998,10598.289999999999,21894.480000000003,15274.61,25285.78,17702.05,13662.65,10956.6,11105.24,10303.24,12357.3,14176.38,19162.49,8498.68,10868.89,14823.91,16537.8,15268.109999999999,10485.69,8746.33,16778.55],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...

# %% [markdown]
#  4. Top 5 products that are bought with other items[link text]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Bought With' is a column in your DataFrame
bought_with_column = reviews_products_list['Bought With']

# Flatten the list of lists into a single list
all_bought_with = [item for sublist in bought_with_column.dropna() for item in sublist]

# Create a pandas Series to easily count the occurrences
bought_with_series = pd.Series(all_bought_with)

# Perform frequency analysis
frequency_analysis = bought_with_series.value_counts().reset_index()
frequency_analysis.columns = ['Product', 'Frequency']

# Select the top 5 products
top_5_products = frequency_analysis.head(5)

# Display the top 5 products and their frequencies in a table
table_data = top_5_products.to_markdown(index=False)
print(table_data)
# Out:
# | Product                          |   Frequency |
# |:---------------------------------|------------:|
# | 27ce55c776a223e8d55c36f1820a5a49 |           9 |
# | 4d2b48662bf193e4e59517d225d887aa |           9 |
# | 7d36c9b72840a33eca0423e2abcd2fce |           8 |
# | 394f7f26c8263c0b62981d4361d76e30 |           8 |
# | 83fc783c88106e492cad4eafc09f9baf |           8 |

# %% [markdown]
# 5. Top 10 brands product

# %% [markdown]
# This graph shows ARIZONO brand has the highest number of products bought

# %%
# Creating brand value count to find the frequency count
brand_counts = reviews_products_list['brand'].value_counts()

# Getting the top 9 brands
top_brands = brand_counts.head(9).index

# Filtering the DataFrame to include only the top brands
filtered_df = reviews_products_list[reviews_products_list['brand'].isin(top_brands)]

# Plotting the bar chart
plt.figure(figsize=(12, 6))
filtered_df['brand'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Products by Top Brands')
plt.xlabel('Brand')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Showing the bar chart
plt.show()
